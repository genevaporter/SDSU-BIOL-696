# %% [markdown]
# # Analyzing Dataset "airquality"

# %%
list.files('~/REPOSITORIES/SDSU-BIOL-696/R-section/in-class-material')
d1 = read.table('~/REPOSITORIES/SDSU-BIOL-696/R-section/in-class-material/RTestData.txt', header=TRUE)
d1
fuso
d1$fuso
attach(d1)
fuso
# Out:
# [1] "KelleyRcode.txt" "output.csv"      "r_inclass1.txt"  "r.py"
# [5] "RTestData.txt"   "test.r"
#    id   strep prev lepto fuso veil time status pocket deepest
# 1  S001 57.4  10.2  0.1   0.0  6.9 1    2      2.7    3.8
# 2  S001 26.0   0.0 25.6   0.0  6.3 2    2      2.7    3.0
# 3  S006 19.0  24.2  4.8   5.7  4.2 1    1      2.5    3.2
# 4  S006 15.2   4.2  0.2   2.6  3.4 2    1      2.4    3.2
# 5  S007 33.2   2.3  7.4   1.3 12.0 1    2      2.4    2.7
# 6  S007 18.0   0.3 13.6   1.7 13.8 2    2      2.4    2.8
# 7  S008 12.3  11.5  9.1   5.5  5.7 1    1      2.6    3.5
# 8  S008  3.3  24.7  6.3  10.4  3.0 2    1      2.5    3.2
# 9  S009  9.1  32.7  1.9  14.3  1.6 1    1      2.9    4.0
# 10 S009 22.0   8.9 17.8   4.8 14.0 2    1      2.5    3.5
# 11 S012 11.0  17.5  8.9   3.4  4.0 1    0      1.6    2.0
# 12 S012  1.8  11.7 29.1   8.4  3.7 2    0      2.5    2.7
# 13 S013  4.8  10.6  3.7  10.5  1.0 1    0      2.4    3.3
# ...

# %% [markdown]
# # Analysong Dataset "ToothGrowth"
